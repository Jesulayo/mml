# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.inception_v3 import InceptionV3
from keras.models import Model
from keras.optimizers import RMSprop
import cv2 
import os
from sklearn.metrics import classification_report,confusion_matrix

# %% [markdown]
# ### Defining Data Paths

# %%
train_path = "C:/Users/Computing/Desktop/data-task1/train"
test_path = "C:/Users/Computing/Desktop/data-task1/test"
val_path = "C:/Users/Computing/Desktop/data-task1/val"

# %% [markdown]
# ### Defining Target Variables

# %%
def data_class(data_path):
    datagen = ImageDataGenerator(rescale = 1./255)
    
    classes = datagen.flow_from_directory(data_path,
                                           target_size = (250, 250),
                                           batch_size = 32,
                                           class_mode = 'categorical')
    return classes

# %%
train_class = data_class(train_path)
test_class = data_class(test_path)
val_class = data_class(val_path)
# Out:
# Found 3000 images belonging to 2 classes.
# Found 500 images belonging to 2 classes.
# Found 500 images belonging to 2 classes.

# %% [markdown]
# ### InceptionV3 Model

# %%
inception_model=InceptionV3(include_top=False, weights='imagenet', input_shape = (250,250,3))

# %% [markdown]
# ### Add extra layers

# %%
result = inception_model.output
x=Flatten()(result)
x=Dense(1024,activation='relu')(x)
x=Dropout(0.2)(x)
x=Dense(256,activation='relu')(x)
x=Dropout(0.2)(x)
x=Dense(1,activation='sigmoid')(x)

# %%
inception=Model(inputs=inception_model.input,outputs=x)

# %%
inception.compile(optimizer=RMSprop(lr=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
inception.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 250, 250, 3  0           []
#                                 )]
#
#  conv2d_376 (Conv2D)            (None, 124, 124, 32  864         ['input_5[0][0]']
#                                 )
#
#  batch_normalization_376 (Batch  (None, 124, 124, 32  96         ['conv2d_376[0][0]']
#  Normalization)                 )
#
#  activation_376 (Activation)    (None, 124, 124, 32  0           ['batch_normalization_376[0][0]']
#                                 )
#
#  conv2d_377 (Conv2D)            (None, 122, 122, 32  9216        ['activation_376[0][0]']
#                                 )
#
#  batch_normalization_377 (Batch  (None, 122, 122, 32  96         ['conv2d_377[0][0]']
#  Normalization)                 )
#
#  activation_377 (Activation)    (None, 122, 122, 32  0           ['batch_normalization_377[0][0]']
#                                 )
#
#  conv2d_378 (Conv2D)            (None, 122, 122, 64  18432       ['activation_377[0][0]']
#                                 )
#
#  batch_normalization_378 (Batch  (None, 122, 122, 64  192        ['conv2d_378[0][0]']
#  Normalization)                 )
#
#  activation_378 (Activation)    (None, 122, 122, 64  0           ['batch_normalization_378[0][0]']
#                                 )
#
#  max_pooling2d_16 (MaxPooling2D  (None, 60, 60, 64)  0           ['activation_378[0][0]']
#  )
#
#  conv2d_379 (Conv2D)            (None, 60, 60, 80)   5120        ['max_pooling2d_16[0][0]']
#
#  batch_normalization_379 (Batch  (None, 60, 60, 80)  240         ['conv2d_379[0][0]']
#  Normalization)
#
#  activation_379 (Activation)    (None, 60, 60, 80)   0           ['batch_normalization_379[0][0]']
#
#  conv2d_380 (Conv2D)            (None, 58, 58, 192)  138240      ['activation_379[0][0]']
#
#  batch_normalization_380 (Batch  (None, 58, 58, 192)  576        ['conv2d_380[0][0]']
#  Normalization)
#
#  activation_380 (Activation)    (None, 58, 58, 192)  0           ['batch_normalization_380[0][0]']
#
#  max_pooling2d_17 (MaxPooling2D  (None, 28, 28, 192)  0          ['activation_380[0][0]']
#  )
#
#  conv2d_384 (Conv2D)            (None, 28, 28, 64)   12288       ['max_pooling2d_17[0][0]']
#
#  batch_normalization_384 (Batch  (None, 28, 28, 64)  192         ['conv2d_384[0][0]']
#  Normalization)
#
#  activation_384 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_384[0][0]']
#
#  conv2d_382 (Conv2D)            (None, 28, 28, 48)   9216        ['max_pooling2d_17[0][0]']
#
#  conv2d_385 (Conv2D)            (None, 28, 28, 96)   55296       ['activation_384[0][0]']
#
#  batch_normalization_382 (Batch  (None, 28, 28, 48)  144         ['conv2d_382[0][0]']
#  Normalization)
#
#  batch_normalization_385 (Batch  (None, 28, 28, 96)  288         ['conv2d_385[0][0]']
#  Normalization)
#
#  activation_382 (Activation)    (None, 28, 28, 48)   0           ['batch_normalization_382[0][0]']
#
#  activation_385 (Activation)    (None, 28, 28, 96)   0           ['batch_normalization_385[0][0]']
#
#  average_pooling2d_36 (AverageP  (None, 28, 28, 192)  0          ['max_pooling2d_17[0][0]']
#  ooling2D)
#
#  conv2d_381 (Conv2D)            (None, 28, 28, 64)   12288       ['max_pooling2d_17[0][0]']
#
#  conv2d_383 (Conv2D)            (None, 28, 28, 64)   76800       ['activation_382[0][0]']
#
#  conv2d_386 (Conv2D)            (None, 28, 28, 96)   82944       ['activation_385[0][0]']
#  conv2d_387 (Conv2D)            (None, 28, 28, 32)   6144        ['average_pooling2d_36[0][0]']
#
#  batch_normalization_381 (Batch  (None, 28, 28, 64)  192         ['conv2d_381[0][0]']
#  Normalization)
#
#  batch_normalization_383 (Batch  (None, 28, 28, 64)  192         ['conv2d_383[0][0]']
#  Normalization)
#
#  batch_normalization_386 (Batch  (None, 28, 28, 96)  288         ['conv2d_386[0][0]']
#  Normalization)
#
#  batch_normalization_387 (Batch  (None, 28, 28, 32)  96          ['conv2d_387[0][0]']
#  Normalization)
#
#  activation_381 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_381[0][0]']
#
#  activation_383 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_383[0][0]']
#
#  activation_386 (Activation)    (None, 28, 28, 96)   0           ['batch_normalization_386[0][0]']
#
#  activation_387 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_387[0][0]']
#
#  mixed0 (Concatenate)           (None, 28, 28, 256)  0           ['activation_381[0][0]',
#                                                                   'activation_383[0][0]',
#                                                                   'activation_386[0][0]',
#                                                                   'activation_387[0][0]']
#
#  conv2d_391 (Conv2D)            (None, 28, 28, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_391 (Batch  (None, 28, 28, 64)  192         ['conv2d_391[0][0]']
#  Normalization)
#
#  activation_391 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_391[0][0]']
#
#  conv2d_389 (Conv2D)            (None, 28, 28, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_392 (Conv2D)            (None, 28, 28, 96)   55296       ['activation_391[0][0]']
#
#  batch_normalization_389 (Batch  (None, 28, 28, 48)  144         ['conv2d_389[0][0]']
#  Normalization)
#
#  batch_normalization_392 (Batch  (None, 28, 28, 96)  288         ['conv2d_392[0][0]']
#  Normalization)
#
#  activation_389 (Activation)    (None, 28, 28, 48)   0           ['batch_normalization_389[0][0]']
#
#  activation_392 (Activation)    (None, 28, 28, 96)   0           ['batch_normalization_392[0][0]']
#
#  average_pooling2d_37 (AverageP  (None, 28, 28, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_388 (Conv2D)            (None, 28, 28, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_390 (Conv2D)            (None, 28, 28, 64)   76800       ['activation_389[0][0]']
#
#  conv2d_393 (Conv2D)            (None, 28, 28, 96)   82944       ['activation_392[0][0]']
#
#  conv2d_394 (Conv2D)            (None, 28, 28, 64)   16384       ['average_pooling2d_37[0][0]']
#
#  batch_normalization_388 (Batch  (None, 28, 28, 64)  192         ['conv2d_388[0][0]']
#  Normalization)
#
#  batch_normalization_390 (Batch  (None, 28, 28, 64)  192         ['conv2d_390[0][0]']
#  Normalization)
#
#  batch_normalization_393 (Batch  (None, 28, 28, 96)  288         ['conv2d_393[0][0]']
#  Normalization)
#
#  batch_normalization_394 (Batch  (None, 28, 28, 64)  192         ['conv2d_394[0][0]']
#  Normalization)
#
#  activation_388 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_388[0][0]']
#
#  activation_390 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_390[0][0]']
#
#  activation_393 (Activation)    (None, 28, 28, 96)   0           ['batch_normalization_393[0][0]']
#
#  activation_394 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_394[0][0]']
#
#  mixed1 (Concatenate)           (None, 28, 28, 288)  0           ['activation_388[0][0]',
#                                                                   'activation_390[0][0]',
#                                                                   'activation_393[0][0]',
#                                                                   'activation_394[0][0]']
#
#  conv2d_398 (Conv2D)            (None, 28, 28, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_398 (Batch  (None, 28, 28, 64)  192         ['conv2d_398[0][0]']
#  Normalization)
#
#  activation_398 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_398[0][0]']
#
#  conv2d_396 (Conv2D)            (None, 28, 28, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_399 (Conv2D)            (None, 28, 28, 96)   55296       ['activation_398[0][0]']
#
#  batch_normalization_396 (Batch  (None, 28, 28, 48)  144         ['conv2d_396[0][0]']
#  Normalization)
#
#  batch_normalization_399 (Batch  (None, 28, 28, 96)  288         ['conv2d_399[0][0]']
#  Normalization)
#
#  activation_396 (Activation)    (None, 28, 28, 48)   0           ['batch_normalization_396[0][0]']
#
#  activation_399 (Activation)    (None, 28, 28, 96)   0           ['batch_normalization_399[0][0]']
#
#  average_pooling2d_38 (AverageP  (None, 28, 28, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_395 (Conv2D)            (None, 28, 28, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_397 (Conv2D)            (None, 28, 28, 64)   76800       ['activation_396[0][0]']
#
#  conv2d_400 (Conv2D)            (None, 28, 28, 96)   82944       ['activation_399[0][0]']
#
#  conv2d_401 (Conv2D)            (None, 28, 28, 64)   18432       ['average_pooling2d_38[0][0]']
#
#  batch_normalization_395 (Batch  (None, 28, 28, 64)  192         ['conv2d_395[0][0]']
#  Normalization)
#
#  batch_normalization_397 (Batch  (None, 28, 28, 64)  192         ['conv2d_397[0][0]']
#  Normalization)
#
#  batch_normalization_400 (Batch  (None, 28, 28, 96)  288         ['conv2d_400[0][0]']
#  Normalization)
#
#  batch_normalization_401 (Batch  (None, 28, 28, 64)  192         ['conv2d_401[0][0]']
#  Normalization)
#
#  activation_395 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_395[0][0]']
#
#  activation_397 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_397[0][0]']
#
#  activation_400 (Activation)    (None, 28, 28, 96)   0           ['batch_normalization_400[0][0]']
#
#  activation_401 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_401[0][0]']
#
#  mixed2 (Concatenate)           (None, 28, 28, 288)  0           ['activation_395[0][0]',
#                                                                   'activation_397[0][0]',
#                                                                   'activation_400[0][0]',
#                                                                   'activation_401[0][0]']
#
#  conv2d_403 (Conv2D)            (None, 28, 28, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_403 (Batch  (None, 28, 28, 64)  192         ['conv2d_403[0][0]']
#  Normalization)
#
#  activation_403 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_403[0][0]']
#
#  conv2d_404 (Conv2D)            (None, 28, 28, 96)   55296       ['activation_403[0][0]']
#
#  batch_normalization_404 (Batch  (None, 28, 28, 96)  288         ['conv2d_404[0][0]']
#  Normalization)
#
#  activation_404 (Activation)    (None, 28, 28, 96)   0           ['batch_normalization_404[0][0]']
#
#  conv2d_402 (Conv2D)            (None, 13, 13, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_405 (Conv2D)            (None, 13, 13, 96)   82944       ['activation_404[0][0]']
#
#  batch_normalization_402 (Batch  (None, 13, 13, 384)  1152       ['conv2d_402[0][0]']
#  Normalization)
#
#  batch_normalization_405 (Batch  (None, 13, 13, 96)  288         ['conv2d_405[0][0]']
#  Normalization)
#
#  activation_402 (Activation)    (None, 13, 13, 384)  0           ['batch_normalization_402[0][0]']
#
#  activation_405 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_405[0][0]']
#
#  max_pooling2d_18 (MaxPooling2D  (None, 13, 13, 288)  0          ['mixed2[0][0]']
#  )
#
#  mixed3 (Concatenate)           (None, 13, 13, 768)  0           ['activation_402[0][0]',
#                                                                   'activation_405[0][0]',
#                                                                   'max_pooling2d_18[0][0]']
#
#  conv2d_410 (Conv2D)            (None, 13, 13, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_410 (Batch  (None, 13, 13, 128)  384        ['conv2d_410[0][0]']
#  Normalization)
#
#  activation_410 (Activation)    (None, 13, 13, 128)  0           ['batch_normalization_410[0][0]']
#
#  conv2d_411 (Conv2D)            (None, 13, 13, 128)  114688      ['activation_410[0][0]']
#
#  batch_normalization_411 (Batch  (None, 13, 13, 128)  384        ['conv2d_411[0][0]']
#  Normalization)
#
#  activation_411 (Activation)    (None, 13, 13, 128)  0           ['batch_normalization_411[0][0]']
#
#  conv2d_407 (Conv2D)            (None, 13, 13, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_412 (Conv2D)            (None, 13, 13, 128)  114688      ['activation_411[0][0]']
#
#  batch_normalization_407 (Batch  (None, 13, 13, 128)  384        ['conv2d_407[0][0]']
#  Normalization)
#
#  batch_normalization_412 (Batch  (None, 13, 13, 128)  384        ['conv2d_412[0][0]']
#  Normalization)
#
#  activation_407 (Activation)    (None, 13, 13, 128)  0           ['batch_normalization_407[0][0]']
#
#  activation_412 (Activation)    (None, 13, 13, 128)  0           ['batch_normalization_412[0][0]']
#
#  conv2d_408 (Conv2D)            (None, 13, 13, 128)  114688      ['activation_407[0][0]']
#
#  conv2d_413 (Conv2D)            (None, 13, 13, 128)  114688      ['activation_412[0][0]']
#
#  batch_normalization_408 (Batch  (None, 13, 13, 128)  384        ['conv2d_408[0][0]']
#  Normalization)
#
#  batch_normalization_413 (Batch  (None, 13, 13, 128)  384        ['conv2d_413[0][0]']
#  Normalization)
#
#  activation_408 (Activation)    (None, 13, 13, 128)  0           ['batch_normalization_408[0][0]']
#
#  activation_413 (Activation)    (None, 13, 13, 128)  0           ['batch_normalization_413[0][0]']
#
#  average_pooling2d_39 (AverageP  (None, 13, 13, 768)  0          ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_406 (Conv2D)            (None, 13, 13, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_409 (Conv2D)            (None, 13, 13, 192)  172032      ['activation_408[0][0]']
#
#  conv2d_414 (Conv2D)            (None, 13, 13, 192)  172032      ['activation_413[0][0]']
#
#  conv2d_415 (Conv2D)            (None, 13, 13, 192)  147456      ['average_pooling2d_39[0][0]']
#
#  batch_normalization_406 (Batch  (None, 13, 13, 192)  576        ['conv2d_406[0][0]']
#  Normalization)
#
#  batch_normalization_409 (Batch  (None, 13, 13, 192)  576        ['conv2d_409[0][0]']
#  Normalization)
#
#  batch_normalization_414 (Batch  (None, 13, 13, 192)  576        ['conv2d_414[0][0]']
#  Normalization)
#
#  batch_normalization_415 (Batch  (None, 13, 13, 192)  576        ['conv2d_415[0][0]']
#  Normalization)
#
#  activation_406 (Activation)    (None, 13, 13, 192)  0           ['batch_normalization_406[0][0]']
#
#  activation_409 (Activation)    (None, 13, 13, 192)  0           ['batch_normalization_409[0][0]']
#
#  activation_414 (Activation)    (None, 13, 13, 192)  0           ['batch_normalization_414[0][0]']
#
#  activation_415 (Activation)    (None, 13, 13, 192)  0           ['batch_normalization_415[0][0]']
#  mixed4 (Concatenate)           (None, 13, 13, 768)  0           ['activation_406[0][0]',
#                                                                   'activation_409[0][0]',
#                                                                   'activation_414[0][0]',
#                                                                   'activation_415[0][0]']
#
#  conv2d_420 (Conv2D)            (None, 13, 13, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_420 (Batch  (None, 13, 13, 160)  480        ['conv2d_420[0][0]']
#  Normalization)
#
#  activation_420 (Activation)    (None, 13, 13, 160)  0           ['batch_normalization_420[0][0]']
#
#  conv2d_421 (Conv2D)            (None, 13, 13, 160)  179200      ['activation_420[0][0]']
#
#  batch_normalization_421 (Batch  (None, 13, 13, 160)  480        ['conv2d_421[0][0]']
#  Normalization)
#
#  activation_421 (Activation)    (None, 13, 13, 160)  0           ['batch_normalization_421[0][0]']
#
#  conv2d_417 (Conv2D)            (None, 13, 13, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_422 (Conv2D)            (None, 13, 13, 160)  179200      ['activation_421[0][0]']
#
#  batch_normalization_417 (Batch  (None, 13, 13, 160)  480        ['conv2d_417[0][0]']
#  Normalization)
#
#  batch_normalization_422 (Batch  (None, 13, 13, 160)  480        ['conv2d_422[0][0]']
#  Normalization)
#
#  activation_417 (Activation)    (None, 13, 13, 160)  0           ['batch_normalization_417[0][0]']
#
#  activation_422 (Activation)    (None, 13, 13, 160)  0           ['batch_normalization_422[0][0]']
#
#  conv2d_418 (Conv2D)            (None, 13, 13, 160)  179200      ['activation_417[0][0]']
#
#  conv2d_423 (Conv2D)            (None, 13, 13, 160)  179200      ['activation_422[0][0]']
#
#  batch_normalization_418 (Batch  (None, 13, 13, 160)  480        ['conv2d_418[0][0]']
#  Normalization)
#
#  batch_normalization_423 (Batch  (None, 13, 13, 160)  480        ['conv2d_423[0][0]']
#  Normalization)
#
#  activation_418 (Activation)    (None, 13, 13, 160)  0           ['batch_normalization_418[0][0]']
#
#  activation_423 (Activation)    (None, 13, 13, 160)  0           ['batch_normalization_423[0][0]']
#
#  average_pooling2d_40 (AverageP  (None, 13, 13, 768)  0          ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_416 (Conv2D)            (None, 13, 13, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_419 (Conv2D)            (None, 13, 13, 192)  215040      ['activation_418[0][0]']
#
#  conv2d_424 (Conv2D)            (None, 13, 13, 192)  215040      ['activation_423[0][0]']
#
#  conv2d_425 (Conv2D)            (None, 13, 13, 192)  147456      ['average_pooling2d_40[0][0]']
#
#  batch_normalization_416 (Batch  (None, 13, 13, 192)  576        ['conv2d_416[0][0]']
#  Normalization)
#
#  batch_normalization_419 (Batch  (None, 13, 13, 192)  576        ['conv2d_419[0][0]']
#  Normalization)
#
#  batch_normalization_424 (Batch  (None, 13, 13, 192)  576        ['conv2d_424[0][0]']
#  Normalization)
#
#  batch_normalization_425 (Batch  (None, 13, 13, 192)  576        ['conv2d_425[0][0]']
#  Normalization)
#
#  activation_416 (Activation)    (None, 13, 13, 192)  0           ['batch_normalization_416[0][0]']
#
#  activation_419 (Activation)    (None, 13, 13, 192)  0           ['batch_normalization_419[0][0]']
#
#  activation_424 (Activation)    (None, 13, 13, 192)  0           ['batch_normalization_424[0][0]']
#
#  activation_425 (Activation)    (None, 13, 13, 192)  0           ['batch_normalization_425[0][0]']
#
#  mixed5 (Concatenate)           (None, 13, 13, 768)  0           ['activation_416[0][0]',
#                                                                   'activation_419[0][0]',
#                                                                   'activation_424[0][0]',
#                                                                   'activation_425[0][0]']
#  conv2d_430 (Conv2D)            (None, 13, 13, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_430 (Batch  (None, 13, 13, 160)  480        ['conv2d_430[0][0]']
#  Normalization)
#
#  activation_430 (Activation)    (None, 13, 13, 160)  0           ['batch_normalization_430[0][0]']
#
#  conv2d_431 (Conv2D)            (None, 13, 13, 160)  179200      ['activation_430[0][0]']
#
#  batch_normalization_431 (Batch  (None, 13, 13, 160)  480        ['conv2d_431[0][0]']
#  Normalization)
#
#  activation_431 (Activation)    (None, 13, 13, 160)  0           ['batch_normalization_431[0][0]']
#
#  conv2d_427 (Conv2D)            (None, 13, 13, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_432 (Conv2D)            (None, 13, 13, 160)  179200      ['activation_431[0][0]']
#
#  batch_normalization_427 (Batch  (None, 13, 13, 160)  480        ['conv2d_427[0][0]']
#  Normalization)
#
#  batch_normalization_432 (Batch  (None, 13, 13, 160)  480        ['conv2d_432[0][0]']
#  Normalization)
#
#  activation_427 (Activation)    (None, 13, 13, 160)  0           ['batch_normalization_427[0][0]']
#
#  activation_432 (Activation)    (None, 13, 13, 160)  0           ['batch_normalization_432[0][0]']
#
#  conv2d_428 (Conv2D)            (None, 13, 13, 160)  179200      ['activation_427[0][0]']
#
#  conv2d_433 (Conv2D)            (None, 13, 13, 160)  179200      ['activation_432[0][0]']
#
#  batch_normalization_428 (Batch  (None, 13, 13, 160)  480        ['conv2d_428[0][0]']
#  Normalization)
#
#  batch_normalization_433 (Batch  (None, 13, 13, 160)  480        ['conv2d_433[0][0]']
#  Normalization)
#
#  activation_428 (Activation)    (None, 13, 13, 160)  0           ['batch_normalization_428[0][0]']
#
#  activation_433 (Activation)    (None, 13, 13, 160)  0           ['batch_normalization_433[0][0]']
#
#  average_pooling2d_41 (AverageP  (None, 13, 13, 768)  0          ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_426 (Conv2D)            (None, 13, 13, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_429 (Conv2D)            (None, 13, 13, 192)  215040      ['activation_428[0][0]']
#
#  conv2d_434 (Conv2D)            (None, 13, 13, 192)  215040      ['activation_433[0][0]']
#
#  conv2d_435 (Conv2D)            (None, 13, 13, 192)  147456      ['average_pooling2d_41[0][0]']
#
#  batch_normalization_426 (Batch  (None, 13, 13, 192)  576        ['conv2d_426[0][0]']
#  Normalization)
#
#  batch_normalization_429 (Batch  (None, 13, 13, 192)  576        ['conv2d_429[0][0]']
#  Normalization)
#
#  batch_normalization_434 (Batch  (None, 13, 13, 192)  576        ['conv2d_434[0][0]']
#  Normalization)
#
#  batch_normalization_435 (Batch  (None, 13, 13, 192)  576        ['conv2d_435[0][0]']
#  Normalization)
#
#  activation_426 (Activation)    (None, 13, 13, 192)  0           ['batch_normalization_426[0][0]']
#
#  activation_429 (Activation)    (None, 13, 13, 192)  0           ['batch_normalization_429[0][0]']
#
#  activation_434 (Activation)    (None, 13, 13, 192)  0           ['batch_normalization_434[0][0]']
#
#  activation_435 (Activation)    (None, 13, 13, 192)  0           ['batch_normalization_435[0][0]']
# ...
#  conv2d_453 (Conv2D)            (None, 6, 6, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_457 (Conv2D)            (None, 6, 6, 384)    1548288     ['activation_456[0][0]']
#
#  batch_normalization_453 (Batch  (None, 6, 6, 384)   1152        ['conv2d_453[0][0]']
#  Normalization)
#
#  batch_normalization_457 (Batch  (None, 6, 6, 384)   1152        ['conv2d_457[0][0]']
#  Normalization)
#
#  activation_453 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_453[0][0]']
#
#  activation_457 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_457[0][0]']
#
#  conv2d_454 (Conv2D)            (None, 6, 6, 384)    442368      ['activation_453[0][0]']
#
#  conv2d_455 (Conv2D)            (None, 6, 6, 384)    442368      ['activation_453[0][0]']
#
#  conv2d_458 (Conv2D)            (None, 6, 6, 384)    442368      ['activation_457[0][0]']
#
#  conv2d_459 (Conv2D)            (None, 6, 6, 384)    442368      ['activation_457[0][0]']
#
#  average_pooling2d_43 (AverageP  (None, 6, 6, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_452 (Conv2D)            (None, 6, 6, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_454 (Batch  (None, 6, 6, 384)   1152        ['conv2d_454[0][0]']
#  Normalization)
#
#  batch_normalization_455 (Batch  (None, 6, 6, 384)   1152        ['conv2d_455[0][0]']
#  Normalization)
#
#  batch_normalization_458 (Batch  (None, 6, 6, 384)   1152        ['conv2d_458[0][0]']
#  Normalization)
#
#  batch_normalization_459 (Batch  (None, 6, 6, 384)   1152        ['conv2d_459[0][0]']
#  Normalization)
#
#  conv2d_460 (Conv2D)            (None, 6, 6, 192)    245760      ['average_pooling2d_43[0][0]']
#
#  batch_normalization_452 (Batch  (None, 6, 6, 320)   960         ['conv2d_452[0][0]']
#  Normalization)
#
#  activation_454 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_454[0][0]']
#
#  activation_455 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_455[0][0]']
#
#  activation_458 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_458[0][0]']
#
#  activation_459 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_459[0][0]']
#
#  batch_normalization_460 (Batch  (None, 6, 6, 192)   576         ['conv2d_460[0][0]']
#  Normalization)
#
#  activation_452 (Activation)    (None, 6, 6, 320)    0           ['batch_normalization_452[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 6, 6, 768)    0           ['activation_454[0][0]',
#                                                                   'activation_455[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 6, 6, 768)    0           ['activation_458[0][0]',
#                                                                   'activation_459[0][0]']
#
#  activation_460 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_460[0][0]']
#
#  mixed9 (Concatenate)           (None, 6, 6, 2048)   0           ['activation_452[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_8[0][0]',
#                                                                   'activation_460[0][0]']
#
#  conv2d_465 (Conv2D)            (None, 6, 6, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_465 (Batch  (None, 6, 6, 448)   1344        ['conv2d_465[0][0]']
#  Normalization)
#
#  activation_465 (Activation)    (None, 6, 6, 448)    0           ['batch_normalization_465[0][0]']
#
#  conv2d_462 (Conv2D)            (None, 6, 6, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_466 (Conv2D)            (None, 6, 6, 384)    1548288     ['activation_465[0][0]']
#
#  batch_normalization_462 (Batch  (None, 6, 6, 384)   1152        ['conv2d_462[0][0]']
#  Normalization)
#
#  batch_normalization_466 (Batch  (None, 6, 6, 384)   1152        ['conv2d_466[0][0]']
#  Normalization)
#
#  activation_462 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_462[0][0]']
#
#  activation_466 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_466[0][0]']
#
#  conv2d_463 (Conv2D)            (None, 6, 6, 384)    442368      ['activation_462[0][0]']
#
#  conv2d_464 (Conv2D)            (None, 6, 6, 384)    442368      ['activation_462[0][0]']
#
#  conv2d_467 (Conv2D)            (None, 6, 6, 384)    442368      ['activation_466[0][0]']
#
#  conv2d_468 (Conv2D)            (None, 6, 6, 384)    442368      ['activation_466[0][0]']
#
#  average_pooling2d_44 (AverageP  (None, 6, 6, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_461 (Conv2D)            (None, 6, 6, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_463 (Batch  (None, 6, 6, 384)   1152        ['conv2d_463[0][0]']
#  Normalization)
#
#  batch_normalization_464 (Batch  (None, 6, 6, 384)   1152        ['conv2d_464[0][0]']
#  Normalization)
#
#  batch_normalization_467 (Batch  (None, 6, 6, 384)   1152        ['conv2d_467[0][0]']
#  Normalization)
#
#  batch_normalization_468 (Batch  (None, 6, 6, 384)   1152        ['conv2d_468[0][0]']
#  Normalization)
#
#  conv2d_469 (Conv2D)            (None, 6, 6, 192)    393216      ['average_pooling2d_44[0][0]']
#
#  batch_normalization_461 (Batch  (None, 6, 6, 320)   960         ['conv2d_461[0][0]']
#  Normalization)
#
#  activation_463 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_463[0][0]']
#
#  activation_464 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_464[0][0]']
#
#  activation_467 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_467[0][0]']
#
#  activation_468 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_468[0][0]']
#
#  batch_normalization_469 (Batch  (None, 6, 6, 192)   576         ['conv2d_469[0][0]']
#  Normalization)
#
#  activation_461 (Activation)    (None, 6, 6, 320)    0           ['batch_normalization_461[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 6, 6, 768)    0           ['activation_463[0][0]',
#                                                                   'activation_464[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 6, 6, 768)    0           ['activation_467[0][0]',
#                                                                   'activation_468[0][0]']
#
#  activation_469 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_469[0][0]']
#
#  mixed10 (Concatenate)          (None, 6, 6, 2048)   0           ['activation_461[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_9[0][0]',
#                                                                   'activation_469[0][0]']
#
#  flatten_3 (Flatten)            (None, 73728)        0           ['mixed10[0][0]']
#
#  dense_7 (Dense)                (None, 1024)         75498496    ['flatten_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 1024)         0           ['dense_7[0][0]']
#
#  dense_8 (Dense)                (None, 256)          262400      ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)            (None, 256)          0           ['dense_8[0][0]']
#
#  dense_9 (Dense)                (None, 1)            257         ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 97,563,937
# Trainable params: 97,529,505
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
history = inception.fit(train_class, validation_data=val_class, epochs=10)
# Out:
# Epoch 1/10
# 20/94 [=====>........................] - ETA: 8:42 - loss: 7.9861 - accuracy: 0.5000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-124e595853c9> in <module>
# ----> 1 history = inception.fit(train_class, validation_data=val_class, epochs=10)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1407                 _r=1):
#    1408               callbacks.on_train_batch_begin(step)
# -> 1409               tmp_logs = self.train_function(iterator)
#    1410               if data_handler.should_sync:
#    1411                 context.async_wait()
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2451       (graph_function,
#    2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453     return graph_function._call_flat(
#    2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2455
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1858         and executing_eagerly):
#    1859       # No tape is watching; skip to running the function.
# -> 1860       return self._build_call_outputs(self._inference_function.call(
#    1861           ctx, args, cancellation_manager=cancellation_manager))
#    1862     forward_backward = self._select_forward_and_backward_functions(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     495       with _InterpolateFunctionError(self):
#     496         if cancellation_manager is None:
# --> 497           outputs = execute.execute(
#     498               str(self.signature.name),
#     499               num_outputs=self._num_outputs,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
